# %% [markdown]
# <a href="https://colab.research.google.com/github/Harikishan63/Harikishan63/blob/main/Pandas_Refresher_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
#

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

# %%
df = pd.read_csv(url, sep='\t')

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#What was the most ordered item in the choice_description column?
c = df.groupby('item_name')
c= c.sum()
c = c.sort_values(['quantity'], ascending=False)
c.head(1)
# Out:
#               order_id  quantity  \
# item_name
# Chicken Bowl    713926       761
#
#                                              choice_description  \
# item_name
# Chicken Bowl  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
#
#                                                      item_price
# item_name
# Chicken Bowl  $16.98 $10.98 $11.25 $8.75 $8.49 $11.25 $8.75 ...

# %%
#turning the data into a aflot
dollar = lambda x: float(x[1:-1])
df.item_price = df.item_price.apply(dollar)

# %%
#how much was the revenue for the period of dataset
revenue = (df['quantity']*df['item_price']).sum()
print('Revenue was: $' + str(np.round(revenue,2)))
# Out:
# Revenue was: $39237.02

# %%
#print a dataframe with only two columns item_name and item_price
orders = df[['item_name','quantity']]

# %%
# delete the duplicates in item_name and quantity
filtered = df.drop_duplicates(['item_name','quantity'])
# select only the products with quantity equals to 1
one_prod = filtered[filtered.quantity == 1]
# select only the item_name and item_price columns
price_per_item = one_prod[['item_name', 'item_price']]
# sort the values from the most to less expensive
price_per_item.sort_values(by = "item_price", ascending = False)
# Out:
#                                   item_name  item_price
# 606                        Steak Salad Bowl       11.89
# 1229                    Barbacoa Salad Bowl       11.89
# 1132                    Carnitas Salad Bowl       11.89
# 7                             Steak Burrito       11.75
# 168                   Barbacoa Crispy Tacos       11.75
# 39                            Barbacoa Bowl       11.75
# 738                       Veggie Soft Tacos       11.25
# 186                       Veggie Salad Bowl       11.25
# 62                              Veggie Bowl       11.25
# 57                           Veggie Burrito       11.25
# 250                           Chicken Salad       10.98
# 5                              Chicken Bowl       10.98
# 8                          Steak Soft Tacos        9.25
# 554                   Carnitas Crispy Tacos        9.25
# 237                     Carnitas Soft Tacos        9.25
# 56                      Barbacoa Soft Tacos        9.25
# ...

# %%
#what was the quantity od the most 5expensive item ordered
df.sort_values(by = "item_price", ascending = False).head(5)
# Out:
#       order_id  quantity                     item_name  \
# 3598      1443        15  Chips and Fresh Tomato Salsa
# 3480      1398         3                 Carnitas Bowl
# 1254       511         4               Chicken Burrito
# 3602      1443         4               Chicken Burrito
# 3601      1443         3                Veggie Burrito
#
#                                      choice_description  item_price
# 3598                                                NaN       44.25
# 3480  [Roasted Chili Corn Salsa, [Fajita Vegetables,...       35.25
# 1254  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       35.00
# 3602  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...       35.00
# 3601  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       33.75

# %%
#how many times were a veggie Salad Bowl ordered?
df[(df.item_name == "Veggie Salad Bowl")].count()
# Out:
# order_id              18
# quantity              18
# item_name             18
# choice_description    18
# item_price            18
# dtype: int64

# %%
# DATASET 2

# %%
df = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv")

# %%
df.head(10)
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
# 6          Argentina            193               25            221
# 7            Armenia             21              179             11
# 8          Australia            261               72            212
# 9            Austria            279               75            191
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# ...

# %%
df.groupby('continent').beer_servings.mean()
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %%
df.groupby('continent').wine_servings.describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %%
#DATASET3

# %%
url='https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv'
crime= pd.read_csv(url)
crime.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
#Converting the type of the column year to datetime64
crime.Year = pd.to_datetime(crime.Year, format='%Y')
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     datetime64[ns]
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: datetime64[ns](1), int64(11)
# memory usage: 5.3 KB

# %%
#Set the Year column as the index of the dataframe¶
crime.set_index('Year', inplace=True)
crime.head()
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
# 1963-01-01   116470              174210   1086400        2297800
# 1964-01-01   130390              203050   1213200        2514400
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200
# 1961-01-01         336000
# ...

# %%
#grouping the year by decades and sum the values
crimes = crime.resample('10AS').sum()

# Uses resample to get the max value only for the "population column"
population = crime['Population'].resample('10AS').max()

# Updating the "Population" column with the "population" series
crimes['Population'] = population

crimes
# Out:
#             Population      Total   Violent   Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   201385000   49295900   4134930   45160900  106180         236720
# 1970-01-01   220099000  100991600   9607930   91383800  192230         554570
# 1980-01-01   248239000  131123369  14074328  117048900  206439         865639
# 1990-01-01   272690813  136582146  17527048  119053499  211664         998827
# 2000-01-01   307006550  115012044  13968056  100944369  163068         922499
# 2010-01-01   318857056   50167967   6072017   44095950   72867         421059
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01  1633510             2158520  13321100       26547700
# 1970-01-01  4159020             4702120  28486000       53157800
# 1980-01-01  5383109             7619130  33073494       72040253
# 1990-01-01  5748930            10568963  26750015       77679366
# 2000-01-01  4230366             8652124  21565176       67970291
# ...

# %%
crimes.head()
# Out:
#             Population      Total   Violent   Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   201385000   49295900   4134930   45160900  106180         236720
# 1970-01-01   220099000  100991600   9607930   91383800  192230         554570
# 1980-01-01   248239000  131123369  14074328  117048900  206439         865639
# 1990-01-01   272690813  136582146  17527048  119053499  211664         998827
# 2000-01-01   307006550  115012044  13968056  100944369  163068         922499
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01  1633510             2158520  13321100       26547700
# 1970-01-01  4159020             4702120  28486000       53157800
# 1980-01-01  5383109             7619130  33073494       72040253
# 1990-01-01  5748930            10568963  26750015       77679366
# 2000-01-01  4230366             8652124  21565176       67970291
#
#             Vehicle_Theft
# Year
# 1960-01-01        5292100
# 1970-01-01        9739900
# ...

# %%
#Return the first 3 rows of the dataframe df.
df = crime

# %%
df.iloc[:3]
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 1962-01-01   185771000  3752200   301510   3450700    8530          17550
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200
# 1961-01-01         336000
# 1962-01-01         366800

# %%
df.loc[:, ['Murder', 'Robbery']].head()
# Out:
#             Murder  Robbery
# Year
# 1960-01-01    9110   107840
# 1961-01-01    8740   106670
# 1962-01-01    8530   110860
# 1963-01-01    8640   116470
# 1964-01-01    9360   130390

# %% [markdown]
# **bold text**# Functioning with basic operations

# %%
#selecting the data in rows[3,4,7] and in columns['Murder', 'Robbery']
df.loc[df.index[[3,4,7]], ['Murder', 'Robbery']]
# Out:
#             Murder  Robbery
# Year
# 1963-01-01    8640   116470
# 1964-01-01    9360   130390
# 1967-01-01   12240   202910

# %%
#Selecting only the rows where the number of murder is greater than 24,000
df[df.Murder > 24000]
# Out:
#             Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1991-01-01   252177000  14872900  1911770  12961100   24700         106590
# 1993-01-01   257908000  14144800  1926020  12218800   24530         106010
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1991-01-01   687730             1092740   3157200        8142200
# 1993-01-01   659870             1135610   2834800        7820900
#
#             Vehicle_Theft
# Year
# 1991-01-01        1661700
# 1993-01-01        1563100

# %%
df[df['Murder'].between(20000, 24000)]
# Out:
#             Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1974-01-01   211392000  10253400   974720   9278700   20710          55400
# 1975-01-01   213124000  11292400  1039710  10252700   20510          56090
# 1979-01-01   220099000  12249500  1208030  11041500   21460          76390
# 1980-01-01   225349264  13408300  1344520  12063700   23040          82990
# 1981-01-01   229146000  13423800  1361820  12061900   22520          82500
# 1982-01-01   231534000  12974400  1322390  11652000   21010          78770
# 1986-01-01   240132887  13211869  1489169  11722700   20613          91459
# 1987-01-01   242282918  13508700  1483999  12024700   20096          91110
# 1988-01-01   245807000  13923100  1566220  12356900   20680          92490
# 1989-01-01   248239000  14251400  1646040  12605400   21500          94500
# 1990-01-01   248709873  14475600  1820130  12655500   23440         102560
# ...

# %%
#Calculating the Mean murder for each different year in df
df.groupby('Year').Murder.mean()
# Out:
# Year
# 1960-01-01     9110.0
# 1961-01-01     8740.0
# 1962-01-01     8530.0
# 1963-01-01     8640.0
# 1964-01-01     9360.0
# 1965-01-01     9960.0
# 1966-01-01    11040.0
# 1967-01-01    12240.0
# 1968-01-01    13800.0
# 1969-01-01    14760.0
# 1970-01-01    16000.0
# 1971-01-01    17780.0
# 1972-01-01    18670.0
# 1973-01-01    19640.0
# 1974-01-01    20710.0
# 1975-01-01    20510.0
# 1976-01-01    18780.0
# 1977-01-01    19120.0
# 1978-01-01    19560.0
# 1979-01-01    21460.0
# 1980-01-01    23040.0
# 1981-01-01    22520.0
# 1982-01-01    21010.0
# 1983-01-01    19310.0
# 1984-01-01    18690.0
# 1985-01-01    18980.0
# 1986-01-01    20613.0
# 1987-01-01    20096.0
# 1988-01-01    20680.0
# 1989-01-01    21500.0
# 1990-01-01    23440.0
# 1991-01-01    24700.0
# 1992-01-01    23760.0
# 1993-01-01    24530.0
# 1994-01-01    23330.0
# 1995-01-01    21610.0
# 1996-01-01    19650.0
# 1997-01-01    18208.0
# 1998-01-01    16914.0
# 1999-01-01    15522.0
# 2000-01-01    15586.0
# ...

# %%
#sort df first by the values in the 'Murder' in descending order,
#then by the values in the 'Violent' column in ascendng order.
df.sort_values(by=['Murder', 'Violent'], ascending=[False, True])
# Out:
#             Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1991-01-01   252177000  14872900  1911770  12961100   24700         106590
# 1993-01-01   257908000  14144800  1926020  12218800   24530         106010
# 1992-01-01   255082000  14438200  1932270  12505900   23760         109060
# 1990-01-01   248709873  14475600  1820130  12655500   23440         102560
# 1994-01-01   260341000  13989500  1857670  12131900   23330         102220
# 1980-01-01   225349264  13408300  1344520  12063700   23040          82990
# 1981-01-01   229146000  13423800  1361820  12061900   22520          82500
# 1995-01-01   262755000  13862700  1798790  12063900   21610          97470
# 1989-01-01   248239000  14251400  1646040  12605400   21500          94500
# 1979-01-01   220099000  12249500  1208030  11041500   21460          76390
# 1982-01-01   231534000  12974400  1322390  11652000   21010          78770
# ...
